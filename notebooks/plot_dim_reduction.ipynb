# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from pathlib import Path
from matplotlib import pyplot as plt
import seaborn as sns

from soul_gan.utils.general_utils import ROOT_DIR, DATA_DIR
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = 'cifar10'
#method = 'umap'
#method = 'tsne' 
method = 'pca'
n = 10000

# %%
model_path = Path(DATA_DIR, dataset, f'{method}.npy')
compressed_data = np.load(model_path)

feature = 'dumb_feature'
exp = 'wgan_gp'

step1 = 0
model_path = Path(ROOT_DIR, 'log', feature, exp, 'dim_reduction', f'{step1}_{method}.npy')
compressed_data1 = np.load(model_path)

step2 = 500
model_path = Path(ROOT_DIR, 'log/dumb_feature/dcgan/dim_reduction', f'{step2}_{method}.npy')
compressed_data2 = np.load(model_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-2a822bed219a> in <module>
#       7 step1 = 0
#       8 model_path = Path(ROOT_DIR, 'log', feature, exp, 'dim_reduction', f'{step1}_{method}.npy')
# ----> 9 compressed_data1 = np.load(model_path)
#      10
#      11 step2 = 500
#
# ~/anaconda3/envs/soul2/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/lagutin/constrained_gen/soul_gan/log/dumb_feature/wgan_gp/dim_reduction/0_pca.npy'

# %%
plt.scatter(compressed_data[:n, 0], compressed_data[:n, 1], alpha=0.01, label=f'{dataset}')
#xlim, ylim = plt.xlim(), plt.ylim()

plt.scatter(compressed_data1[:n, 0], compressed_data[:n, 1], alpha=0.01, label=f'{step1}')

plt.scatter(compressed_data2[:n, 0], compressed_data[:n, 1], alpha=0.01, label=f'{step2}')

leg = plt.legend()
for lh in leg.legendHandles: 
    lh.set_alpha(1)

#handles, labels = plt.legend_elements(prop="sizes", alpha=0.6)
#plt.legend()
#plt.xlim(xlim)
#plt.ylim(ylim)

plt.savefig(f'../figs/dim_reduction/{dataset}_{exp}_{method}.png')

# %%
feature = 'dumb_feature'
exp = 'dcgan'

step = 0
model_path = Path(ROOT_DIR, 'log', feature, exp, 'dim_reduction', f'{step}_{method}.npy')
compressed_data1 = np.load(model_path)

# %%
plt.scatter(compressed_data[:n, 0], compressed_data[:n, 1], alpha=0.01)
plt.xlim(xlim)
plt.ylim(ylim)
plt.savefig(f'../figs/dim_reduction/{exp}_{method}_{step}.png')

# %%
step = 500
model_path = Path(ROOT_DIR, 'log/dumb_feature/dcgan/dim_reduction', f'{step}_{method}.npy')
compressed_data = np.load(model_path)

# %%
plt.scatter(compressed_data[:n, 0], compressed_data[:n, 1], alpha=0.01)
plt.xlim(xlim)
plt.ylim(ylim)
plt.savefig(f'../figs/dim_reduction/{exp}_{method}_{step}.png')
